# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.xkcd()

# %%
x = np.linspace(1,10,45)
y = np.sin(x)+np.cos(x)+np.tan(x)

# %%
y[y>10] = np.inf
y[y<-10] = -np.inf

# %%
plt.plot(y)
