# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 一、臺北市立動物園_動物資料

# %%
df = pd.read_csv("https://data.taipei/api/getDatasetInfo/downloadResource?id=5cb73231-b741-48b3-bec3-2ef57bb10029&rid=a3e2b221-75e0-45c1-8f97-75acbd43d613")

# %%
df
# Out:
#     A_Name_Ch    A_Summary    A_Keywords A_AlsoKnown  \
# 0         大貓熊  請於入園時領取參觀票券  大貓熊;圓仔;團團;圓圓         NaN
# 1        國王企鵝          NaN       企鵝；國王企鵝         NaN
# 2        黑腳企鵝          NaN           NaN         NaN
# 3        弓角羚羊          NaN           NaN         NaN
# 4        非洲野驢          NaN           NaN         NaN
# 5        單峰駱駝          NaN           NaN         NaN
# 6        雙峰駱駝          NaN           NaN         NaN
# 7          人猿          NaN           NaN         NaN
# 8        大長臂猿          NaN           NaN         NaN
# 9       印度大犀鳥          NaN           NaN         NaN
# 10        亞洲象          NaN            大象         NaN
# 11       孟加拉虎          NaN            老虎         NaN
# 12         花豹          NaN           NaN         NaN
# 13        馬來熊          NaN           NaN         NaN
# 14        馬來貘          NaN           NaN         NaN
# 15        黑天鵝          NaN           NaN         NaN
# 16      白手長臂猿          NaN           NaN         NaN
# ...

# %% [markdown]
# ### 翻轉dataframe

# %%
df = df.T

# %%
df
# Out:
#                                                                 0    \
# A_Name_Ch                                                       大貓熊
# A_Summary                                               請於入園時領取參觀票券
# A_Keywords                                             大貓熊;圓仔;團團;圓圓
# A_AlsoKnown                                                     NaN
# A_Geo                         MULTIPOINT ((121.5831587 24.9971109))
# A_Location                                              新光特展館(大貓熊館)
# A_POIGroup                                                      NaN
# A_Name_En                                               Giant Panda
# A_Name_Latin                                 Ailuropoda melanoleuca
# A_Phylum                                      Phylum Chordata 脊索動物門
# A_Class                                          Class Mammalia 哺乳綱
# A_Order                                         Order Carnivora 食肉目
# A_Family                                          Family Ursidae 熊科
# ...

# %% [markdown]
# ### 刪除不必要的資料

# %%
df = df.drop(df.index[13:46])

# %%
df
# Out:
#                                                 0    \
# A_Name_Ch                                       大貓熊
# A_Summary                               請於入園時領取參觀票券
# A_Keywords                             大貓熊;圓仔;團團;圓圓
# A_AlsoKnown                                     NaN
# A_Geo         MULTIPOINT ((121.5831587 24.9971109))
# A_Location                              新光特展館(大貓熊館)
# A_POIGroup                                      NaN
# A_Name_En                               Giant Panda
# A_Name_Latin                 Ailuropoda melanoleuca
# A_Phylum                      Phylum Chordata 脊索動物門
# A_Class                          Class Mammalia 哺乳綱
# A_Order                         Order Carnivora 食肉目
# A_Family                          Family Ursidae 熊科
#
#                                                 1    \
# A_Name_Ch                                      國王企鵝
# A_Summary                                       NaN
# A_Keywords                                  企鵝；國王企鵝
# ...

# %%
df = df.drop(df.index[1:5])

# %%
df = df.drop(df.index[2])

# %%
df
# Out:
#                                  0                        1    \
# A_Name_Ch                        大貓熊                     國王企鵝
# A_Location               新光特展館(大貓熊館)                      企鵝館
# A_Name_En                Giant Panda             King Penguin
# A_Name_Latin  Ailuropoda melanoleuca  Aptenodytes patagonicus
# A_Phylum       Phylum Chordata 脊索動物門                    脊索動物門
# A_Class           Class Mammalia 哺乳綱                       鳥綱
# A_Order          Order Carnivora 食肉目                      企鵝目
# A_Family           Family Ursidae 熊科                      企鵝科
#
#                              2                    3    \
# A_Name_Ch                   黑腳企鵝                 弓角羚羊
# A_Location                   企鵝館                沙漠動物區
# A_Name_En        Jackass penguin                Addax
# A_Name_Latin  Spheniscus demersu  Addax nasomaculatus
# A_Phylum                   脊索動物門                脊索動物門
# A_Class                       鳥綱                  哺乳綱
# ...

# %%
df = df.T

# %%
df.columns = ['中文名','館區','英文名','學名','分類學_門','分類學_綱','分類學_目','分類學_科']

# %%
df
# Out:
#          中文名                 館區                                         英文名  \
# 0        大貓熊        新光特展館(大貓熊館)                                 Giant Panda
# 1       國王企鵝                企鵝館                                King Penguin
# 2       黑腳企鵝                企鵝館                             Jackass penguin
# 3       弓角羚羊              沙漠動物區                                       Addax
# 4       非洲野驢              沙漠動物區                            African wild ass
# 5       單峰駱駝              沙漠動物區            Dromedary Camel或One-humped Camel
# 6       雙峰駱駝        沙漠動物區;兒童動物區              Bactrian Camel或Two-humped Came
# 7         人猿              熱帶雨林區                                   Orangutan
# 8       大長臂猿              熱帶雨林區                                     Siamang
# 9      印度大犀鳥              熱帶雨林區                        Great Indian Horbill
# 10       亞洲象              熱帶雨林區                            Asiatic Elephant
# ...

# %% [markdown]
# ### 列出屬脊索動物門、鳥綱、雁形目、雁鴨科的所有動物

# %%
df[(df.分類學_門=="脊索動物門")&(df.分類學_綱=='鳥綱')&(df.分類學_目=='雁形目')&(df.分類學_科=='雁鴨科')]
# Out:
#       中文名     館區                 英文名                      學名  分類學_門 分類學_綱  \
# 15    黑天鵝  熱帶雨林區          Black Swan          Cygnus atratus  脊索動物門    鳥綱
# 241  美洲木鴨    鳥園區  American Wood Duck              Aix sponsa  脊索動物門    鳥綱
# 288   黑天鵝    鳥園區          Black Swan          Cygnus atratus  脊索動物門    鳥綱
# 289   綠頭鴨    鳥園區             Mallard      Anas platyrhynchos  脊索動物門    鳥綱
# 290   埃及雁    鳥園區     Egyptian Goose?  Alopochen aegyptiacus?  脊索動物門    鳥綱
# 291    鴛鴦    鳥園區       Mandarin Duck        Aix galericulata  脊索動物門    鳥綱
#
#     分類學_目 分類學_科
# 15    雁形目   雁鴨科
# 241   雁形目   雁鴨科
# 288   雁形目   雁鴨科
# 289   雁形目   雁鴨科
# 290   雁形目   雁鴨科
# 291   雁形目   雁鴨科

# %% [markdown]
# ## 二、健保門診及住院就診人次統計-腸病毒

# %%
sick = pd.read_csv("https://quality.data.gov.tw/dq_download_csv.php?nid=14590&md5_url=94da77489a0804657722211edfb5c12c")

# %%
sick
# Out:
#            年   週 就診類別    年齡別   縣市  腸病毒健保就診人次  健保就診總人次
# 0       2008  14   住院    0-2  台中市          0      105
# 1       2008  14   住院    0-2  台北市          2      151
# 2       2008  14   住院    0-2  台東縣          0       14
# 3       2008  14   住院    0-2  台南市          0       20
# 4       2008  14   住院    0-2  宜蘭縣          0       44
# 5       2008  14   住院    0-2  花蓮縣          0       17
# 6       2008  14   住院    0-2  金門縣          0        1
# 7       2008  14   住院    0-2  屏東縣          0       19
# 8       2008  14   住院    0-2  苗栗縣          0        1
# 9       2008  14   住院    0-2  桃園市          0      141
# 10      2008  14   住院    0-2  高雄市          2       87
# 11      2008  14   住院    0-2  基隆市          0       21
# 12      2008  14   住院    0-2  雲林縣          0        3
# 13      2008  14   住院    0-2  新北市          0       42
# 14      2008  14   住院    0-2  新竹市          0       39
# 15      2008  14   住院    0-2  新竹縣          0        6
# ...

# %% [markdown]
# ### 將腸病毒健保就診人次大於1500的紀錄按照人次由高排到低

# %%
sick = sick[(sick.腸病毒健保就診人次>1500)]

# %%
sick.sort_values(by='腸病毒健保就診人次',ascending=False)
# Out:
#           年   週 就診類別  年齡別   縣市  腸病毒健保就診人次  健保就診總人次
# 25410  2010  27   門診  5-9  新北市       2925    50125
# 68611  2014  23   門診  5-9  新北市       2869    49034
# 68821  2014  24   門診  5-9  新北市       2785    50469
# 68401  2014  22   門診  5-9  新北市       2711    52373
# 69032  2014  25   門診  5-9  新北市       2494    47971
# 24985  2010  25   門診  5-9  新北市       2422    47021
# 25198  2010  26   門診  5-9  新北市       2330    41716
# 25621  2010  28   門診  5-9  新北市       2153    45395
# 68806  2014  24   門診  5-9  台中市       2099    36455
# 68386  2014  22   門診  5-9  台中市       2092    39640
# 68596  2014  23   門診  5-9  台中市       2047    35965
# 69245  2014  26   門診  5-9  新北市       1977    46283
# 57650  2013  23   門診  5-9  台中市       1974    35862
# 2514   2008  25   門診  5-9  台中市       1969    45600
# 46870  2012  24   門診  5-9  新北市       1963    45322
# 68190  2014  21   門診  5-9  新北市       1953    52058
# 25395  2010  27   門診  5-9  台中市       1930    41110
# ...
